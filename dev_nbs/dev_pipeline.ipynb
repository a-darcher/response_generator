# %%
from response_stats.pipeline import *

# %%
config = {
    # general
    "n_samples": 10,
    "save_dir": Path("/media/al/darch/response_stats/datasets/tests"),
    "save_language": "python",

    # baseline- or response-type
    "response_type": "response",

    # trial params
    "trial_range": [10,100],       # int | tuple | list

    # time params
    "baseline_T": -1,        # float
    "stimulus_T": 1,        # float
    "dt": 0.001,                # float

    # response shape - beta params
    "beta_a_range": [1,1.5],      # tuple | list
    "beta_multiplier_range": [1.5, 2],  # tuple | list

    # response duration params
    "duration_range": [0.25, 0.7],    # float | tuple | list

    # delay in response onset param
    "latency_range": [0.25, 0.41],     # float | tuple | list

    "induce_refractory_period": True,

    # supplementary trials params
    "generate_supplementary_trials": True,
    "supplementary_default_count": 200,

    # random seed
    "seed": 73,

    # baseline firing rate params
    "baseline_threshold": False,
    "baseline_scale": False,
    "baseline_range": [0.1, 15],   # tuple | list | bool

    # peak response firing rate params
    "response_fr_sampler": "uniform",
    "response_fr_method": "linear_function",
    "response_fr_scale": 2,
    "response_fr_max": 100,

    # gain response function
    "gain_response_threshold": False,
    "gain_response_y": False,
    "gain_response_high": False,
    "gain_response_e": False,

    # linear response function
    "linear_response_slope": 2,
    "linear_response_offset": 5,
}

# %%
cfg = SimulationConfig(**config)

# %%
run(cfg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 run(cfg)
#
# File ~/Documents/code/generate_responses/src/response_stats/pipeline.py:486, in run(config)
#     485 def run(config: SimulationConfig) -> pd.DataFrame:
# --> 486     return ResponseSimulator(config).run()
#
# File ~/Documents/code/generate_responses/src/response_stats/pipeline.py:274, in ResponseSimulator.run(self)
#     268 latencies = self._handle_latencies()
#     270 response_bool = 1 if cfg.response_type == "response" else 0
#     272 df = pd.DataFrame({
#     273     "n_trials": trial_counts.astype(dtype=np.int32),
# --> 274     "n_supp_trials": supplement_trials_counts.astype(dtype=np.int32),
#     275     "response": np.full(cfg.n_samples, response_bool, dtype=str),
#     276     "fr_baseline": fr_baseline.astype(float),
#     277     "fr_response": fr_response.astype(float),
# ...
